# %%
# Convert intersections parquet to csv for validation
parquet_file = '/home/capheus/projects/helios_density_test/200_leaf_60_JoshOutput/valid_rays/leg_0_valid_rays.parquet'
output_file = '/home/capheus/projects/helios_density_test/200_leaf_60_JoshOutput/valid_rays/leg_0_valid_ray.csv'

import utils

utils.convert_parquet_to_csv(parquet_file, output_file)
