# %%
# Convert intersections parquet to csv for validation
parquet_file = ['/home/capheus/projects/024_Trees/valid_rays/leg_0_voxel_2.0_intersections.parquet']
reference_file = '/home/capheus/projects/024_Trees/references/024_grouped_voxel_size_2.0.csv'

import utils

utils.calculate_occlusion_metrics(intersections_files=parquet_file, reference_file=reference_file)
# utils.convert_parquet_to_csv(parquet_file, output_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       3 reference_file = '/home/capheus/projects/024_Trees/references/024_grouped_voxel_size_2.0.csv'
#       5 import utils
# ----> 7 utils.calculate_occlusion_metrics(intersections_files=parquet_file, reference_file=reference_file)
#       8 # utils.convert_parquet_to_csv(parquet_file, output_file)
#
# File ~/PlantDensityAnalysis/utils.py:2502, in calculate_occlusion_metrics(intersections_files, reference_file, max_beam_distance, heat_map_resolution, debug, epsilon)
#    2499 ### DEBUG ###
#    2500 voxel_occ_df, voxel_heatmaps = get_occlusion_per_voxel(voxel_grouped.get_group(first_voxel_id))
# -> 2502 voxel_occlusion_df, voxel_heatmaps = voxel_intersections_df.groupby('voxel_id').apply(get_occlusion_per_voxel).reset_index(drop=True)
#    2504 # Create UV maps for voels
#    2505 return voxel_occlusion_df
#
# ValueError: too many values to unpack (expected 2)
